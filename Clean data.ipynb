# %%
import os
import pandas as pd
import glob
import math
import numpy as np

# %%
# Read the 2017 csv file into a pandas DataFrame
lsd = pd.read_csv('201701-citibike-tripdata.csv/201701-citibike-tripdata.csv')
lsd1 = pd.read_csv('201701-citibike-tripdata.csv/201702-citibike-tripdata.csv')
lsd2 = pd.read_csv('201701-citibike-tripdata.csv/201703-citibike-tripdata.csv')
lsd3 = pd.read_csv('201701-citibike-tripdata.csv/201704-citibike-tripdata.csv')
lsd4 = pd.read_csv('201701-citibike-tripdata.csv/201705-citibike-tripdata.csv')
lsd5 = pd.read_csv('201701-citibike-tripdata.csv/201706-citibike-tripdata.csv')
lsd6 = pd.read_csv('201701-citibike-tripdata.csv/201707-citibike-tripdata.csv')
lsd7 = pd.read_csv('201701-citibike-tripdata.csv/201708-citibike-tripdata.csv')
lsd8 = pd.read_csv('201701-citibike-tripdata.csv/201709-citibike-tripdata.csv')
lsd9 = pd.read_csv('201701-citibike-tripdata.csv/201710-citibike-tripdata.csv')
lsd10 = pd.read_csv('201701-citibike-tripdata.csv/201711-citibike-tripdata.csv')
lsd11 = pd.read_csv('201701-citibike-tripdata.csv/201712-citibike-tripdata.csv')

# %%
#Reviewed the pd, and column names do not match with csv files from April 2017. changed January to March 2017 to lowercase
lsd.columns = lsd.columns.str.lower()
lsd1.columns = lsd1.columns.str.lower()
lsd2.columns = lsd2.columns.str.lower()

# %%
#change column name to match other spreasheet
lsd= lsd.rename(columns= {"trip duration":"tripduration","start time":"starttime","stop time":"stoptime","bike id": "bikeid","user type": "usertype"})

# %%
#change column name to match other spreasheet
lsd1= lsd1.rename(columns= {"trip duration":"tripduration","start time":"starttime","stop time":"stoptime","bike id": "bikeid","user type": "usertype"})
lsd2 =lsd2.rename(columns= {"trip duration":"tripduration","start time":"starttime","stop time":"stoptime","bike id": "bikeid","user type": "usertype"})

# %%
#concatnate all 2017 csv files
result10 = pd.concat([lsd, lsd1,lsd2],sort=False)
result10
# Out:
#         tripduration            starttime             stoptime  \
# 0                680  2017-01-01 00:00:21  2017-01-01 00:11:41
# 1               1282  2017-01-01 00:00:45  2017-01-01 00:22:08
# 2                648  2017-01-01 00:00:57  2017-01-01 00:11:46
# 3                631  2017-01-01 00:01:10  2017-01-01 00:11:42
# 4                621  2017-01-01 00:01:25  2017-01-01 00:11:47
# 5                666  2017-01-01 00:01:51  2017-01-01 00:12:57
# 6                559  2017-01-01 00:05:00  2017-01-01 00:14:20
# 7                826  2017-01-01 00:05:37  2017-01-01 00:19:24
# 8                255  2017-01-01 00:05:47  2017-01-01 00:10:02
# 9                634  2017-01-01 00:07:34  2017-01-01 00:18:08
# 10              1081  2017-01-01 00:07:49  2017-01-01 00:25:50
# 11               479  2017-01-01 00:08:00  2017-01-01 00:15:59
# 12              2005  2017-01-01 00:05:57  2017-01-01 00:39:23
# 13               738  2017-01-01 00:08:50  2017-01-01 00:21:09
# ...

# %%
result_summer_months17 = pd.concat([lsd4,lsd5,lsd6, lsd7],sort=False)
result_summer_months17
# Out:
#          tripduration            starttime             stoptime  \
# 0                 254  2017-05-01 00:00:13  2017-05-01 00:04:27
# 1                 248  2017-05-01 00:00:19  2017-05-01 00:04:28
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id         end station name  \
# 0               -73.993929             505          6 Ave & W 33 St
# ...

# %%
result_summer_months_18 = pd.concat([df4,df5,df6,df7], axis=0)
result_summer_months_18
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 367  2018-05-01 05:06:16.5840  2018-05-01 05:12:23.9650
# 1                1313  2018-05-01 06:25:49.4250  2018-05-01 06:47:42.7120
# 2                1798  2018-05-01 06:40:26.4450  2018-05-01 07:10:25.1790
# 3                 518  2018-05-01 07:06:02.9730  2018-05-01 07:14:41.0040
# 4                 109  2018-05-01 07:26:32.3450  2018-05-01 07:28:21.5420
# 5                 461  2018-05-01 07:28:02.9610  2018-05-01 07:35:44.8240
# 6                1713  2018-05-01 07:57:59.1810  2018-05-01 08:26:33.0490
# 7                 423  2018-05-01 07:57:59.3890  2018-05-01 08:05:02.7260
# 8                 978  2018-05-01 08:01:16.6680  2018-05-01 08:17:35.6080
# 9                 472  2018-05-01 08:07:06.9110  2018-05-01 08:14:59.4060
# 10                460  2018-05-01 08:08:23.9910  2018-05-01 08:16:04.4840
# 11                383  2018-05-01 08:10:22.0970  2018-05-01 08:16:45.7450
# ...

# %%
#concatnate all 2018 csv files
result9 = pd.concat([df9,df10,df11], axis=0)
result9.head()

# %%
#concatnate all 2017 and 2018 csv files
summer17_18 = pd.concat([result_summer_months17, result_summer_months_18], axis=0)
summer17_18
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 254       2017-05-01 00:00:13       2017-05-01 00:04:27
# 1                 248       2017-05-01 00:00:19       2017-05-01 00:04:28
# 2                1120       2017-05-01 00:00:19       2017-05-01 00:19:00
# 3                 212       2017-05-01 00:00:24       2017-05-01 00:03:56
# 4                 686       2017-05-01 00:00:29       2017-05-01 00:11:55
# 5                 577       2017-05-01 00:00:35       2017-05-01 00:10:12
# 6                 523       2017-05-01 00:00:41       2017-05-01 00:09:24
# 7                 419       2017-05-01 00:00:45       2017-05-01 00:07:44
# 8                 518       2017-05-01 00:00:47       2017-05-01 00:09:25
# 9                1296       2017-05-01 00:00:48       2017-05-01 00:22:25
# 10                418       2017-05-01 00:00:59       2017-05-01 00:07:58
# 11                589       2017-05-01 00:01:00       2017-05-01 00:10:50
# ...

# %%
long=(summer17_18['end station longitude']-summer17_18['start station longitude'])
lat= (summer17_18['end station latitude']-summer17_18['start station latitude'])
R= 3958.8
long
lat
w=(np.sin(lat/2))**2
x=np.cos(summer17_18['start station latitude'])
y=np.cos(summer17_18['end station latitude'])
z=(np.sin(long/2))**2
z
a = (np.sin(lat/2))**2 + np.cos(summer17_18['start station latitude']) * np.cos(summer17_18['end station latitude']) * (np.sin(long/2))**2
C =2 * np.arctan2( np.sqrt(a), np.sqrt(1-a) )
summer17_18['Distance in Miles']=C*R # d= R dot c  #(where R is the radius of the Earth)
summer17_18
summer17_18.insert(15, 'Distance in Miles', float, allow_duplicates = False)

# %%
#read 2018 to csv
result_summer_months_18.to_csv("citybike182.csv")

# %%
summer17_18.to_csv("summer17_18.csv")

# %%
#read 2017 to csv
result10.to_csv("citybike171.csv")
result11.to_csv("citybike172.csv")

# %%
#read 2017 to csv
result9.to_csv("citybike181.csv")
result11.to_csv("citybike182.csv")
