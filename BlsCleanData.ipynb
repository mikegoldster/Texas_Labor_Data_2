# %%
import pandas as pd
import json
import geopandas as gpd

# %%
df=pd.read_excel('oes00ma/msa_2000_dl_2.xls')
df3=pd.read_excel('oesm03ma/msa_may2003_dl_2.xls')
df6=pd.read_excel('oesm06ma/MSA_may2006_dl_3.xls')
df9=pd.read_excel('oesm09ma/MSA_dl_3.xls')
df12=pd.read_excel('oesm12ma/MSA_M2012_dl_3_OH_WY.xls')
df15=pd.read_excel('oesm15ma/MSA_M2015_dl.xlsx')
df18=pd.read_excel('oesm18ma/MSA_M2018_dl.xlsx')

# %%
df3["Year"] = "2003"
df6["Year"] = "2006"
df9["Year"] = "2009"
df12["Year"] = "2012"
df15["Year"] = "2015"
df18["Year"] = "2018"

# %%
df_2000=df.loc[lambda df: df['prim_state'] == "TX"]

# %%
df_2003=df3.loc[lambda df3: df3['PRIM_STATE'] == "TX"]

# %%
df_2006=df6.loc[lambda df6: df6['PRIM_STATE'] == "TX"]

# %%
df_2009=df9.loc[lambda df9: df9['PRIM_STATE'] == "TX"]

# %%
df_2012=df12.loc[lambda df12: df12['PRIM_STATE'] == "TX"]

# %%
df_2015=df15.loc[lambda df15: df15['PRIM_STATE'] == "TX"]
df_2015
# Out:
#        PRIM_STATE   AREA          AREA_NAME OCC_CODE  \
# 131329         TX  10180        Abilene, TX  00-0000
# 131330         TX  10180        Abilene, TX  11-0000
# 131331         TX  10180        Abilene, TX  11-1021
# 131332         TX  10180        Abilene, TX  11-2022
# 131333         TX  10180        Abilene, TX  11-3011
# 131334         TX  10180        Abilene, TX  11-3021
# 131335         TX  10180        Abilene, TX  11-3031
# 131336         TX  10180        Abilene, TX  11-3051
# 131337         TX  10180        Abilene, TX  11-3071
# 131338         TX  10180        Abilene, TX  11-9021
# 131339         TX  10180        Abilene, TX  11-9032
# 131340         TX  10180        Abilene, TX  11-9033
# 131341         TX  10180        Abilene, TX  11-9051
# 131342         TX  10180        Abilene, TX  11-9081
# 131343         TX  10180        Abilene, TX  11-9111
# 131344         TX  10180        Abilene, TX  11-9141
# 131345         TX  10180        Abilene, TX  11-9199
# ...

# %%
df_2018=df18.loc[lambda df18: df18['PRIM_STATE'] == "TX"]

# %%
df_2000=df_2000.rename(columns={"prim_state": 'PRIM_STATE','area_name':'AREA_NAME', 'occ_titl':'OCC_TITLE', 'tot_emp':'TOT_EMP', 'h_mean':'H_MEAN', 'a_mean':'A_MEAN', 'year':'Year' })

# %%
new_df2000=df_2000[['PRIM_STATE','AREA_NAME','OCC_TITLE','TOT_EMP','H_MEAN','A_MEAN','Year']]

# %%
new_df2003=df_2003[['PRIM_STATE','AREA_NAME','OCC_TITLE','TOT_EMP','H_MEAN','A_MEAN','Year']]

# %%
new_df2006=df_2006[['PRIM_STATE','AREA_NAME','OCC_TITLE','TOT_EMP','H_MEAN','A_MEAN','Year']]

# %%
new_df2009=df_2009[['PRIM_STATE','AREA_NAME','OCC_TITLE','TOT_EMP','H_MEAN','A_MEAN','Year']]

# %%
new_df2012=df_2012[['PRIM_STATE','AREA_NAME','OCC_TITLE','TOT_EMP','H_MEAN','A_MEAN','Year']]

# %%
new_df2015=df_2015[['PRIM_STATE','AREA_NAME','OCC_TITLE','TOT_EMP','H_MEAN','A_MEAN','Year']]
new_df2015
# Out:
#        PRIM_STATE          AREA_NAME  \
# 131329         TX        Abilene, TX
# 131330         TX        Abilene, TX
# 131331         TX        Abilene, TX
# 131332         TX        Abilene, TX
# 131333         TX        Abilene, TX
# 131334         TX        Abilene, TX
# 131335         TX        Abilene, TX
# 131336         TX        Abilene, TX
# 131337         TX        Abilene, TX
# 131338         TX        Abilene, TX
# 131339         TX        Abilene, TX
# 131340         TX        Abilene, TX
# 131341         TX        Abilene, TX
# 131342         TX        Abilene, TX
# 131343         TX        Abilene, TX
# 131344         TX        Abilene, TX
# 131345         TX        Abilene, TX
# 131346         TX        Abilene, TX
# 131347         TX        Abilene, TX
# 131348         TX        Abilene, TX
# 131349         TX        Abilene, TX
# 131350         TX        Abilene, TX
# 131351         TX        Abilene, TX
# 131352         TX        Abilene, TX
# ...

# %%
new_df2018=df_2018[['PRIM_STATE','AREA_NAME','OCC_TITLE','TOT_EMP','H_MEAN','A_MEAN','Year']]
new_df2018
# Out:
#        PRIM_STATE          AREA_NAME  \
# 118265         TX        Abilene, TX
# 118266         TX        Abilene, TX
# 118267         TX        Abilene, TX
# 118268         TX        Abilene, TX
# 118269         TX        Abilene, TX
# 118270         TX        Abilene, TX
# 118271         TX        Abilene, TX
# 118272         TX        Abilene, TX
# 118273         TX        Abilene, TX
# 118274         TX        Abilene, TX
# 118275         TX        Abilene, TX
# 118276         TX        Abilene, TX
# 118277         TX        Abilene, TX
# 118278         TX        Abilene, TX
# 118279         TX        Abilene, TX
# 118280         TX        Abilene, TX
# 118281         TX        Abilene, TX
# 118282         TX        Abilene, TX
# 118283         TX        Abilene, TX
# 118284         TX        Abilene, TX
# 118285         TX        Abilene, TX
# 118286         TX        Abilene, TX
# 118287         TX        Abilene, TX
# 118288         TX        Abilene, TX
# ...

# %%
dfAllyearsnew=new_df2000.append([ new_df2003, new_df2006,new_df2009,new_df2015,new_df2012, new_df2018],  sort=False)

# %%
dfAllyearsnew1=dfAllyearsnew.rename(columns={'PRIM_STATE':'State',"AREA_NAME": "REGION","OCC_TITLE": "Occupation","TOT_EMP": "Total_Employee","H_MEAN": "Hourly_Mean","A_MEAN": "Annual_Mean"})

# %%
dfAllyearsnew1['Total_Employee'] = dfAllyearsnew1['Total_Employee'].replace('**', '0')
dfAllyearsnew1['Hourly_Mean'] = dfAllyearsnew1['Hourly_Mean'].replace('*', '0')
dfAllyearsnew1['Annual_Mean'] = dfAllyearsnew1['Annual_Mean'].replace('*', '0')

# %%
dfAllyearsnew1['Annual_Mean'] = dfAllyearsnew1['Annual_Mean'].replace('***', '0')
dfAllyearsnew1['Hourly_Mean'] = dfAllyearsnew1['Hourly_Mean'].replace('#', '0')
dfAllyearsnew1['Annual_Mean'] = dfAllyearsnew1['Annual_Mean'].replace('#', '0')
dfAllyearsnew1['Total_Employee']= dfAllyearsnew1['Total_Employee'].astype(str).astype(float)
dfAllyearsnew1['Hourly_Mean']= dfAllyearsnew1['Hourly_Mean'].astype(str).astype(float)
dfAllyearsnew1['Annual_Mean']= dfAllyearsnew1['Annual_Mean'].astype(str).astype(float)

# %%
dfAllyears.to_csv('dfAllyears.csv')

# %%
with open('C:/Users/joyet/Downloads/tx_counties.geojson', 'r') as f:
    data = json.load(f)
df = pd.DataFrame(data)

# %%
df06=pd.read_csv('May2006.csv')
df09=pd.read_csv('May2009.csv')
df12_a=pd.read_csv('May2012.csv')
df15_a=pd.read_csv('May2015.csv')
df18_=pd.read_csv('May2018.csv')

# %%
df_06=df06.loc[lambda df06: df06['PRIM_STATE'] == "TX"]
df_06
# Out:
#        YEAR PRIM_STATE     AREA                                AREA_NAME  \
# 44078  2006         TX  4800001  Northwestern Texas nonmetropolitan area
# 44079  2006         TX  4800001  Northwestern Texas nonmetropolitan area
# 44080  2006         TX  4800001  Northwestern Texas nonmetropolitan area
# 44081  2006         TX  4800001  Northwestern Texas nonmetropolitan area
# 44082  2006         TX  4800001  Northwestern Texas nonmetropolitan area
# 44083  2006         TX  4800001  Northwestern Texas nonmetropolitan area
# 44084  2006         TX  4800001  Northwestern Texas nonmetropolitan area
# 44085  2006         TX  4800001  Northwestern Texas nonmetropolitan area
# 44086  2006         TX  4800001  Northwestern Texas nonmetropolitan area
# 44087  2006         TX  4800001  Northwestern Texas nonmetropolitan area
# 44088  2006         TX  4800001  Northwestern Texas nonmetropolitan area
# 44089  2006         TX  4800001  Northwestern Texas nonmetropolitan area
# ...

# %%
df_09=df09.loc[lambda df09: df09['PRIM_STATE'] == "TX"]
df_09
# Out:
#        YEAR PRIM_STATE     AREA                                AREA_NAME  \
# 45219  2009         TX  4800001  Northwestern Texas nonmetropolitan area
# 45220  2009         TX  4800001  Northwestern Texas nonmetropolitan area
# 45221  2009         TX  4800001  Northwestern Texas nonmetropolitan area
# 45222  2009         TX  4800001  Northwestern Texas nonmetropolitan area
# 45223  2009         TX  4800001  Northwestern Texas nonmetropolitan area
# 45224  2009         TX  4800001  Northwestern Texas nonmetropolitan area
# 45225  2009         TX  4800001  Northwestern Texas nonmetropolitan area
# 45226  2009         TX  4800001  Northwestern Texas nonmetropolitan area
# 45227  2009         TX  4800001  Northwestern Texas nonmetropolitan area
# 45228  2009         TX  4800001  Northwestern Texas nonmetropolitan area
# 45229  2009         TX  4800001  Northwestern Texas nonmetropolitan area
# 45230  2009         TX  4800001  Northwestern Texas nonmetropolitan area
# ...

# %%
df_12=df12_a.loc[lambda df12_a: df12_a['PRIM_STATE'] == "TX"]
df_12
# Out:
#        YEAR PRIM_STATE     AREA                                AREA_NAME  \
# 45535  2012         TX  4800001  Northwestern Texas nonmetropolitan area
# 45536  2012         TX  4800001  Northwestern Texas nonmetropolitan area
# 45537  2012         TX  4800001  Northwestern Texas nonmetropolitan area
# 45538  2012         TX  4800001  Northwestern Texas nonmetropolitan area
# 45539  2012         TX  4800001  Northwestern Texas nonmetropolitan area
# 45540  2012         TX  4800001  Northwestern Texas nonmetropolitan area
# 45541  2012         TX  4800001  Northwestern Texas nonmetropolitan area
# 45542  2012         TX  4800001  Northwestern Texas nonmetropolitan area
# 45543  2012         TX  4800001  Northwestern Texas nonmetropolitan area
# 45544  2012         TX  4800001  Northwestern Texas nonmetropolitan area
# 45545  2012         TX  4800001  Northwestern Texas nonmetropolitan area
# 45546  2012         TX  4800001  Northwestern Texas nonmetropolitan area
# ...

# %%
df_15=df15_a.loc[lambda df15_a: df15_a['PRIM_STATE'] == "TX"]
df_15
# Out:
#        YEAR PRIM_STATE     AREA  \
# 42810  2015         TX  4800001
# 42811  2015         TX  4800001
# 42812  2015         TX  4800001
# 42813  2015         TX  4800001
# 42814  2015         TX  4800001
# 42815  2015         TX  4800001
# 42816  2015         TX  4800001
# 42817  2015         TX  4800001
# 42818  2015         TX  4800001
# 42819  2015         TX  4800001
# 42820  2015         TX  4800001
# 42821  2015         TX  4800001
# 42822  2015         TX  4800001
# 42823  2015         TX  4800001
# 42824  2015         TX  4800001
# 42825  2015         TX  4800001
# 42826  2015         TX  4800001
# 42827  2015         TX  4800001
# 42828  2015         TX  4800001
# 42829  2015         TX  4800001
# 42830  2015         TX  4800001
# 42831  2015         TX  4800001
# 42832  2015         TX  4800001
# 42833  2015         TX  4800001
# 42834  2015         TX  4800001
# 42835  2015         TX  4800001
# 42836  2015         TX  4800001
# 42837  2015         TX  4800001
# ...

# %%
df_18=df18_.loc[lambda df18_: df18_['PRIM_STATE'] == "TX"]
df_18
# Out:
#        YEAR PRIM_STATE     AREA  \
# 38715  2018         TX  4800001
# 38716  2018         TX  4800001
# 38717  2018         TX  4800001
# 38718  2018         TX  4800001
# 38719  2018         TX  4800001
# 38720  2018         TX  4800001
# 38721  2018         TX  4800001
# 38722  2018         TX  4800001
# 38723  2018         TX  4800001
# 38724  2018         TX  4800001
# 38725  2018         TX  4800001
# 38726  2018         TX  4800001
# 38727  2018         TX  4800001
# 38728  2018         TX  4800001
# 38729  2018         TX  4800001
# 38730  2018         TX  4800001
# 38731  2018         TX  4800001
# 38732  2018         TX  4800001
# 38733  2018         TX  4800001
# 38734  2018         TX  4800001
# 38735  2018         TX  4800001
# 38736  2018         TX  4800001
# 38737  2018         TX  4800001
# 38738  2018         TX  4800001
# 38739  2018         TX  4800001
# 38740  2018         TX  4800001
# 38741  2018         TX  4800001
# 38742  2018         TX  4800001
# ...

# %%
new_df06=df_06[['PRIM_STATE','AREA_NAME','OCC_TITLE','TOT_EMP','H_MEAN','A_MEAN','YEAR']]
new_df06
# Out:
#       PRIM_STATE                                AREA_NAME  \
# 44078         TX  Northwestern Texas nonmetropolitan area
# 44079         TX  Northwestern Texas nonmetropolitan area
# 44080         TX  Northwestern Texas nonmetropolitan area
# 44081         TX  Northwestern Texas nonmetropolitan area
# 44082         TX  Northwestern Texas nonmetropolitan area
# 44083         TX  Northwestern Texas nonmetropolitan area
# 44084         TX  Northwestern Texas nonmetropolitan area
# 44085         TX  Northwestern Texas nonmetropolitan area
# 44086         TX  Northwestern Texas nonmetropolitan area
# 44087         TX  Northwestern Texas nonmetropolitan area
# 44088         TX  Northwestern Texas nonmetropolitan area
# 44089         TX  Northwestern Texas nonmetropolitan area
# 44090         TX  Northwestern Texas nonmetropolitan area
# 44091         TX  Northwestern Texas nonmetropolitan area
# 44092         TX  Northwestern Texas nonmetropolitan area
# ...

# %%
new_df09=df_09[['PRIM_STATE','AREA_NAME','OCC_TITLE','TOT_EMP','H_MEAN','A_MEAN','YEAR']]
new_df09
# Out:
#       PRIM_STATE                                AREA_NAME  \
# 45219         TX  Northwestern Texas nonmetropolitan area
# 45220         TX  Northwestern Texas nonmetropolitan area
# 45221         TX  Northwestern Texas nonmetropolitan area
# 45222         TX  Northwestern Texas nonmetropolitan area
# 45223         TX  Northwestern Texas nonmetropolitan area
# 45224         TX  Northwestern Texas nonmetropolitan area
# 45225         TX  Northwestern Texas nonmetropolitan area
# 45226         TX  Northwestern Texas nonmetropolitan area
# 45227         TX  Northwestern Texas nonmetropolitan area
# 45228         TX  Northwestern Texas nonmetropolitan area
# 45229         TX  Northwestern Texas nonmetropolitan area
# 45230         TX  Northwestern Texas nonmetropolitan area
# 45231         TX  Northwestern Texas nonmetropolitan area
# 45232         TX  Northwestern Texas nonmetropolitan area
# 45233         TX  Northwestern Texas nonmetropolitan area
# ...

# %%
new_df12=df_12[['PRIM_STATE','AREA_NAME','OCC_TITLE','TOT_EMP','H_MEAN','A_MEAN','YEAR']]
new_df12
# Out:
#       PRIM_STATE                                AREA_NAME  \
# 45535         TX  Northwestern Texas nonmetropolitan area
# 45536         TX  Northwestern Texas nonmetropolitan area
# 45537         TX  Northwestern Texas nonmetropolitan area
# 45538         TX  Northwestern Texas nonmetropolitan area
# 45539         TX  Northwestern Texas nonmetropolitan area
# 45540         TX  Northwestern Texas nonmetropolitan area
# 45541         TX  Northwestern Texas nonmetropolitan area
# 45542         TX  Northwestern Texas nonmetropolitan area
# 45543         TX  Northwestern Texas nonmetropolitan area
# 45544         TX  Northwestern Texas nonmetropolitan area
# 45545         TX  Northwestern Texas nonmetropolitan area
# 45546         TX  Northwestern Texas nonmetropolitan area
# 45547         TX  Northwestern Texas nonmetropolitan area
# 45548         TX  Northwestern Texas nonmetropolitan area
# 45549         TX  Northwestern Texas nonmetropolitan area
# ...

# %%
new_df15=df_15[['PRIM_STATE','AREA_NAME','OCC_TITLE','TOT_EMP','H_MEAN','A_MEAN','YEAR']]
new_df15
# Out:
#       PRIM_STATE                                          AREA_NAME  \
# 42810         TX    West Texas Region of Texas nonmetropolitan area
# 42811         TX    West Texas Region of Texas nonmetropolitan area
# 42812         TX    West Texas Region of Texas nonmetropolitan area
# 42813         TX    West Texas Region of Texas nonmetropolitan area
# 42814         TX    West Texas Region of Texas nonmetropolitan area
# 42815         TX    West Texas Region of Texas nonmetropolitan area
# 42816         TX    West Texas Region of Texas nonmetropolitan area
# 42817         TX    West Texas Region of Texas nonmetropolitan area
# 42818         TX    West Texas Region of Texas nonmetropolitan area
# 42819         TX    West Texas Region of Texas nonmetropolitan area
# 42820         TX    West Texas Region of Texas nonmetropolitan area
# 42821         TX    West Texas Region of Texas nonmetropolitan area
# 42822         TX    West Texas Region of Texas nonmetropolitan area
# ...

# %%
new_df18=df_18[['PRIM_STATE','AREA_NAME','OCC_TITLE','TOT_EMP','H_MEAN','A_MEAN','YEAR']]
new_df18
# Out:
#       PRIM_STATE                                          AREA_NAME  \
# 38715         TX    West Texas Region of Texas nonmetropolitan area
# 38716         TX    West Texas Region of Texas nonmetropolitan area
# 38717         TX    West Texas Region of Texas nonmetropolitan area
# 38718         TX    West Texas Region of Texas nonmetropolitan area
# 38719         TX    West Texas Region of Texas nonmetropolitan area
# 38720         TX    West Texas Region of Texas nonmetropolitan area
# 38721         TX    West Texas Region of Texas nonmetropolitan area
# 38722         TX    West Texas Region of Texas nonmetropolitan area
# 38723         TX    West Texas Region of Texas nonmetropolitan area
# 38724         TX    West Texas Region of Texas nonmetropolitan area
# 38725         TX    West Texas Region of Texas nonmetropolitan area
# 38726         TX    West Texas Region of Texas nonmetropolitan area
# 38727         TX    West Texas Region of Texas nonmetropolitan area
# ...

# %%
dfAllyears1=new_df06.append([ new_df09, new_df12,new_df15,new_df18],  sort=False)

# %%
dfAllyears1=dfAllyears1.rename(columns={'PRIM_STATE':'State',"AREA_NAME": "REGION","OCC_TITLE": "Occupation","TOT_EMP": "Total_Employee","H_MEAN": "Hourly_Mean","A_MEAN": "Annual_Mean",'YEAR':'Year'})

# %%
dfAllyears1['Total_Employee'] = dfAllyears1['Total_Employee'].replace('**', '0')
dfAllyears1['Hourly_Mean'] = dfAllyears1['Hourly_Mean'].replace('*', '0')
dfAllyears1['Annual_Mean'] = dfAllyears1['Annual_Mean'].replace('*', '0')

# %%
dfAllyears1['Annual_Mean'] = dfAllyears1['Annual_Mean'].replace('***', '0')
dfAllyears1['Hourly_Mean'] = dfAllyears1['Hourly_Mean'].replace('#', '0')
dfAllyears1['Annual_Mean'] = dfAllyears1['Annual_Mean'].replace('#', '0')
#dfAllyears1['Total_Employee']= dfAllyears1['Total_Employee'].astype(str).astype(float)
dfAllyears1['Hourly_Mean']= dfAllyears1['Hourly_Mean'].astype(str).astype(float)
#dfAllyears1['Annual_Mean']= dfAllyears1['Annual_Mean'].astype(str).astype(float)

# %%
dfAllyears1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11252 entries, 44078 to 40981
# Data columns (total 7 columns):
# State             11252 non-null object
# REGION            11252 non-null object
# Occupation        11252 non-null object
# Total_Employee    11252 non-null object
# Hourly_Mean       11252 non-null float64
# Annual_Mean       11252 non-null object
# Year              11252 non-null int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 703.2+ KB

# %%
dfAllyears1.to_csv('dfAllyears1.csv')

# %%
Jul_29_data=dfAllyearsnew1.append([dfAllyears1],  sort=False)
Jul_29_data
# Out:
#       State                                             REGION  \
# 39872    TX                                    Abilene, TX MSA
# 39873    TX                                    Abilene, TX MSA
# 39874    TX                                    Abilene, TX MSA
# 39875    TX                                    Abilene, TX MSA
# 39876    TX                                    Abilene, TX MSA
# 39877    TX                                    Abilene, TX MSA
# 39878    TX                                    Abilene, TX MSA
# 39879    TX                                    Abilene, TX MSA
# 39880    TX                                    Abilene, TX MSA
# 39881    TX                                    Abilene, TX MSA
# 39882    TX                                    Abilene, TX MSA
# 39883    TX                                    Abilene, TX MSA
# 39884    TX                                    Abilene, TX MSA
# 39885    TX                                    Abilene, TX MSA
# ...

# %%
Jul_29_data.to_csv('Jul_29_data.csv')

# %%
dfgeo=pd.read_csv('geodf.csv',low_memory=False)
dfgeo1=pd.read_csv('dfAllyears1.csv',low_memory=False)
dfgeo2=pd.read_csv('testYears.csv',low_memory=False)

# %%
dfAllyears1=dfgeo1.append([ dfgeo2],  sort=False)

# %%
dfAllyears1
# Out:
#        Unnamed: 0 State         REGION  \
# 0             0.0    TX     West Texas
# 1             1.0    TX     West Texas
# 2             2.0    TX     West Texas
# 3             3.0    TX     West Texas
# 4             4.0    TX     West Texas
# 5             5.0    TX     West Texas
# 6             6.0    TX     West Texas
# 7             7.0    TX     West Texas
# 8             8.0    TX     West Texas
# 9             9.0    TX     West Texas
# 10           10.0    TX     West Texas
# 11           11.0    TX     West Texas
# 12           12.0    TX     West Texas
# 13           13.0    TX     West Texas
# 14           14.0    TX     West Texas
# 15           15.0    TX     West Texas
# 16           16.0    TX     West Texas
# 17           17.0    TX     West Texas
# 18           18.0    TX     West Texas
# 19           19.0    TX     West Texas
# 20           20.0    TX     West Texas
# 21           21.0    TX     West Texas
# 22           22.0    TX     West Texas
# ...

# %%
#testYears3= pd.merge(dfAllyears1,df1, on= 'REGION', how= 'left' )
dfAllyears1.to_csv('dfAllyears1.csv')

# %%
dfAllyears2=dfAllyears1.append([ dfgeo],  sort=False)

# %%
dfAllyears2
# Out:
#         Unnamed: 0 State          REGION  \
# 0              0.0    TX      West Texas
# 1              1.0    TX      West Texas
# 2              2.0    TX      West Texas
# 3              3.0    TX      West Texas
# 4              4.0    TX      West Texas
# 5              5.0    TX      West Texas
# 6              6.0    TX      West Texas
# 7              7.0    TX      West Texas
# 8              8.0    TX      West Texas
# 9              9.0    TX      West Texas
# 10            10.0    TX      West Texas
# 11            11.0    TX      West Texas
# 12            12.0    TX      West Texas
# 13            13.0    TX      West Texas
# 14            14.0    TX      West Texas
# 15            15.0    TX      West Texas
# 16            16.0    TX      West Texas
# 17            17.0    TX      West Texas
# 18            18.0    TX      West Texas
# 19            19.0    TX      West Texas
# 20            20.0    TX      West Texas
# 21            21.0    TX      West Texas
# ...

# %%
dfAllyears4=pd.read_csv('Jul_29_data.csv',low_memory=False)

# %%
dfAllyears2['State']= dfAllyears2['State'].replace('NaN', 'TX')

# %%
dfAllyears2
# Out:
#         Unnamed: 0 State          REGION  \
# 0              0.0    TX      West Texas
# 1              1.0    TX      West Texas
# 2              2.0    TX      West Texas
# 3              3.0    TX      West Texas
# 4              4.0    TX      West Texas
# 5              5.0    TX      West Texas
# 6              6.0    TX      West Texas
# 7              7.0    TX      West Texas
# 8              8.0    TX      West Texas
# 9              9.0    TX      West Texas
# 10            10.0    TX      West Texas
# 11            11.0    TX      West Texas
# 12            12.0    TX      West Texas
# 13            13.0    TX      West Texas
# 14            14.0    TX      West Texas
# 15            15.0    TX      West Texas
# 16            16.0    TX      West Texas
# 17            17.0    TX      West Texas
# 18            18.0    TX      West Texas
# 19            19.0    TX      West Texas
# 20            20.0    TX      West Texas
# 21            21.0    TX      West Texas
# ...

# %%
dfAllyears2.to_csv('dfAllyears2.csv')

# %%
dfAllyears1=pd.read_csv('dfAllyears1.csv',low_memory=False)

# %%
dfAllyears4.head()
# Out:
#   State   REGION                       Occupation Total_Employee  Hourly_Mean  \
# 0    TX  Abilene                  All Occupations          62670        13.77
# 1    TX  Abilene           Management occupations           2150        33.04
# 2    TX  Abilene                 Chief executives             70        61.93
# 3    TX  Abilene  General and operations managers            910        36.85
# 4    TX  Abilene                   Sales managers             50        39.85
#
#   Annual_Mean  Year
# 0       28650  2006
# 1       68720  2006
# 2      128810  2006
# 3       76640  2006
# 4       82880  2006

# %%
dfAllyears4['Occupation'] = dfAllyears4['Occupation'].str.upper()
dfAllyears4.head()
# Out:
#   State   REGION                       Occupation Total_Employee  Hourly_Mean  \
# 0    TX  Abilene                  ALL OCCUPATIONS          62670        13.77
# 1    TX  Abilene           MANAGEMENT OCCUPATIONS           2150        33.04
# 2    TX  Abilene                 CHIEF EXECUTIVES             70        61.93
# 3    TX  Abilene  GENERAL AND OPERATIONS MANAGERS            910        36.85
# 4    TX  Abilene                   SALES MANAGERS             50        39.85
#
#   Annual_Mean  Year
# 0       28650  2006
# 1       68720  2006
# 2      128810  2006
# 3       76640  2006
# 4       82880  2006

# %%
dfAllyears4.to_csv('Jul_29_dataN.csv')
