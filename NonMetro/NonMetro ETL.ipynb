# %%
import pandas as pd

# %%
frames=[]
for x in range(2006,2019):
    dfs=pd.read_csv(f'May{x}.csv')
    frames.append(dfs)

# %%
df=frames[0]
df.head()
# Out:
#    YEAR PRIM_STATE    AREA                              AREA_NAME OCC_CODE  \
# 0  2006         AK  200001  Southeast Alaska nonmetropolitan area  00-0000
# 1  2006         AK  200001  Southeast Alaska nonmetropolitan area  11-0000
# 2  2006         AK  200001  Southeast Alaska nonmetropolitan area  11-1011
# 3  2006         AK  200001  Southeast Alaska nonmetropolitan area  11-1021
# 4  2006         AK  200001  Southeast Alaska nonmetropolitan area  11-1031
#
#                          OCC_TITLE  GROUP TOT_EMP EMP_PRSE H_MEAN  ...    \
# 0                  All Occupations    NaN   35250      2.2  19.87  ...
# 1           Management occupations  major    2950      4.0  31.25  ...
# 2                 Chief executives    NaN     200      9.3  43.36  ...
# 3  General and operations managers    NaN    1010      5.7  31.13  ...
# 4                      Legislators    NaN      60     28.3      *  ...
#
#   H_MEDIAN H_PCT75 H_PCT90 A_PCT10 A_PCT25 A_MEDIAN A_PCT75 A_PCT90 ANNUAL  \
# ...

# %%
for x in range(0,11):
    if frames[x]['PRIM_STATE'] == 'TX':
# Out:
#        YEAR PRIM_STATE     AREA                                  AREA_NAME  \
# 0      2008         AK   200001      Southeast Alaska nonmetropolitan area
# 1      2008         AK   200001      Southeast Alaska nonmetropolitan area
# 2      2008         AK   200001      Southeast Alaska nonmetropolitan area
# 3      2008         AK   200001      Southeast Alaska nonmetropolitan area
# 4      2008         AK   200001      Southeast Alaska nonmetropolitan area
# 5      2008         AK   200001      Southeast Alaska nonmetropolitan area
# 6      2008         AK   200001      Southeast Alaska nonmetropolitan area
# 7      2008         AK   200001      Southeast Alaska nonmetropolitan area
# 8      2008         AK   200001      Southeast Alaska nonmetropolitan area
# 9      2008         AK   200001      Southeast Alaska nonmetropolitan area
# 10     2008         AK   200001      Southeast Alaska nonmetropolitan area
# ...
