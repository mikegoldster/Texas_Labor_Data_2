# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
texas_labor = "Employment_Data/Combined_Data.csv"

texas_df = pd.read_csv(texas_labor)
texas_df
# Out:
#                                  Location       Occupation  \
# 0                            Abilene, TX   All Occupations
# 1                           Amarillo, TX   All Occupations
# 2                   Austin-San Marcos, TX  All Occupations
# 3               Beaumont-Port Arthur, TX   All Occupations
# 4   Brownsville-Harlingen-San Benito, TX   All Occupations
# 5              Bryan-College Station, TX   All Occupations
# 6                     Corpus Christi, TX   All Occupations
# 7                             Dallas, TX   All Occupations
# 8                            El Paso, TX   All Occupations
# 9               Fort Worth-Arlington, TX   All Occupations
# 10                           Houston, TX   All Occupations
# 11                    Killeen-Temple, TX   All Occupations
# 12                            Laredo, TX   All Occupations
# 13                 Longview-Marshall, TX   All Occupations
# 14                           Lubbock, TX   All Occupations
# ...

# %%
texas_df.shape
# Out:
# (25, 28)

# %%
texas_em = texas_df.drop(columns=['2003 Hourly Mean','2006 Hourly Mean','2009 Hourly Mean','2012 Hourly Mean',
                                   '2015 Hourly Mean', '2003 Hourly Median','2006 Hourly Median','2009 Hourly Median',
                                  '2012 Hourly Median','2015 Hourly Median', '2003 Annual Median','2006 Annual Median','2009 Annual Median','2012 Annual Median',
                                   '2015 Annual Median', '2003 Annual Mean', '2006 Annual Mean', '2009 Annual Mean', '2012 Annual Mean',
                                    '2015 Annual Mean' ])

# %%
texas_em.count()
# Out:
# Location                25
# Occupation              25
# 2003 Total Employees    25
# 2006 Total Employees    25
# 2009 Total Employees    25
# 2012 Total Employees    25
# 2015 Total Employees    25
# 2018 Total Employees    25
# dtype: int64

# %%
texas_em = texas_em.rename(columns = {'2003 Total Employees':2003,'2006 Total Employees':2006,'2009 Total Employees':2009,
                    '2012 Total Employees':2012,'2015 Total Employees':2015, '2018 Total Employees':2018})

# %%
texas_em[2012]=texas_em[2012].str.replace(',','').astype(float)
texas_em[2015]=texas_em[2015].str.replace(',','').astype(float)

# %%
texas_em
# Out:
#                                  Location       Occupation     2003     2006  \
# 0                            Abilene, TX   All Occupations    53600    62670
# 1                           Amarillo, TX   All Occupations    95500   106470
# 2                   Austin-San Marcos, TX  All Occupations   651670   711080
# 3               Beaumont-Port Arthur, TX   All Occupations   153080   154910
# 4   Brownsville-Harlingen-San Benito, TX   All Occupations   112320   117680
# 5              Bryan-College Station, TX   All Occupations    75500    88910
# 6                     Corpus Christi, TX   All Occupations   157030   170810
# 7                             Dallas, TX   All Occupations  1890340  1990180
# 8                            El Paso, TX   All Occupations   251970   258140
# 9               Fort Worth-Arlington, TX   All Occupations   764710   818690
# 10                           Houston, TX   All Occupations  2057880  2378080
# ...

# %%
i = 1
for location in texas_em['Location'].unique():
    texas_em.loc[texas_em['Location'] == location, "Loc ID"] = i
    i= i+1

# %%
texas_em['Loc ID'] = texas_em['Loc ID'].astype(int)

# %%
texas_em
# Out:
#                                  Location       Occupation     2003     2006  \
# 0                            Abilene, TX   All Occupations    53600    62670
# 1                           Amarillo, TX   All Occupations    95500   106470
# 2                   Austin-San Marcos, TX  All Occupations   651670   711080
# 3               Beaumont-Port Arthur, TX   All Occupations   153080   154910
# 4   Brownsville-Harlingen-San Benito, TX   All Occupations   112320   117680
# 5              Bryan-College Station, TX   All Occupations    75500    88910
# 6                     Corpus Christi, TX   All Occupations   157030   170810
# 7                             Dallas, TX   All Occupations  1890340  1990180
# 8                            El Paso, TX   All Occupations   251970   258140
# 9               Fort Worth-Arlington, TX   All Occupations   764710   818690
# 10                           Houston, TX   All Occupations  2057880  2378080
# ...

# %%
plt.figure(figsize = (10,6))
plt.plot(texas_em[[2003, 2006, 2009, 2012, 2015]])
plt.xlabel ("Count of Total Employees per Region")
plt.ylabel("Total Employees")
plt.legend(texas_em[[2003, 2006, 2009, 2012, 2015]])

# %%
texas_em.shape
# Out:
# (25, 9)

# %%
x_data = texas_em[[2003,2006, 2009, 2012, 2015]].values

# %%
x_data.shape
# Out:
# (25, 5)

# %%
texas_em
# Out:
#                                  Location       Occupation     2003     2006  \
# 0                            Abilene, TX   All Occupations    53600    62670
# 1                           Amarillo, TX   All Occupations    95500   106470
# 2                   Austin-San Marcos, TX  All Occupations   651670   711080
# 3               Beaumont-Port Arthur, TX   All Occupations   153080   154910
# 4   Brownsville-Harlingen-San Benito, TX   All Occupations   112320   117680
# 5              Bryan-College Station, TX   All Occupations    75500    88910
# 6                     Corpus Christi, TX   All Occupations   157030   170810
# 7                             Dallas, TX   All Occupations  1890340  1990180
# 8                            El Paso, TX   All Occupations   251970   258140
# 9               Fort Worth-Arlington, TX   All Occupations   764710   818690
# 10                           Houston, TX   All Occupations  2057880  2378080
# ...

# %%
y_data = texas_em[[2018]]
# get 2018 actual

# %%
y_data.shape
# Out:
# (25, 1)

# %%
texas_em.iloc[:,2:7].values.reshape(25, -1)
# Out:
# array([[  53600.,   62670.,   63330.,   62020.,   65070.],
#        [  95500.,  106470.,  108690.,  109750.,  114450.],
#        [ 651670.,  711080.,  769370.,  812600.,  928810.],
#        [ 153080.,  154910.,  159930.,  157320.,  164920.],
#        [ 112320.,  117680.,  122990.,  125870.,  135710.],
#        [  75500.,   88910.,   91360.,   92990.,  189000.],
#        [ 157030.,  170810.,  177750.,  181240.,  189000.],
#        [1890340., 1990180., 2047600., 2097080., 2329820.],
#        [ 251970.,  258140.,  269250.,  275400.,  290630.],
#        [ 764710.,  818690.,  856430.,  879300.,  973010.],
#        [2057880., 2378080., 2563840., 2640640., 2929970.],
#        [ 100720.,  113000.,  121180.,  127320.,  132490.],
#        [  74770.,   82410.,   86940.,   90020.,   96340.],
#        [  91060.,   88160.,   94330.,   98130.,   98530.],
#        [ 115560.,  122380.,  123840.,  125800.,  137110.],
#        [ 176900.,  203380.,  220110.,  227710.,  243340.],
# ...

# %%
texas_em.iloc[:,7].values.reshape(25, -1)
# Out:
# array([[  64300],
#        [ 114830],
#        [1028500],
#        [ 159560],
#        [ 138510],
#        [ 114040],
#        [ 187540],
#        [3568180],
#        [ 304900],
#        [1001591],
#        [2982420],
#        [ 138520],
#        [  99900],
#        [  91920],
#        [ 142240],
#        [ 260260],
#        [  76540],
#        [  45880],
#        [1011640],
#        [  44890],
#        [  55680],
#        [ 101740],
#        [  39450],
#        [ 116430],
#        [  57020]], dtype=int64)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(texas_em.iloc[:,2:7].values.reshape(25, -1),
                                                   texas_em.iloc[:,7].values.reshape(25, -1),
                                                    random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
model.coef_
# Out:
# array([[  1.9539023 ,   8.64701769, -15.06346482,   5.98829452,
#           0.42634875]])

# %%
X_test
# Out:
# array([[251970., 258140., 269250., 275400., 290630.],
#        [102280.,  60170.,  67570.,  68070.,  75380.],
#        [ 53600.,  62670.,  63330.,  62020.,  65070.],
#        [ 93520.,  97530.,  99480., 100300., 109740.],
#        [100720., 113000., 121180., 127320., 132490.],
#        [764710., 818690., 856430., 879300., 973010.],
#        [ 91060.,  88160.,  94330.,  98130.,  98530.]])

# %%
model.predict(X_test)
# Out:
# array([[ 382783.23258489],
#        [  83128.41856352],
#        [  32874.25234965],
#        [ 116041.72850068],
#        [ 108505.15415527],
#        [1294010.5123332 ],
#        [  90015.44826862]])

# %%
y_test
# Out:
# array([[ 304900],
#        [  76540],
#        [  64300],
#        [ 116430],
#        [ 138520],
#        [1001591],
#        [  91920]], dtype=int64)

# %% [markdown]
# troops in Fort Hood went to Iraq in 2004 roughly 40,000 soliders where deported

# %%
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.9990701847153768
# Testing Score: 0.8639756093971213

# %%
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="Testing Data")
plt.legend()
plt.title("Residual Plot")
# Out:
# Text(0.5, 1.0, 'Residual Plot')

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()  
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([[ 382783.23258489],
#        [  83128.41856352],
#        [  32874.25234965],
#        [ 116041.72850068],
#        [ 108505.15415527],
#        [1294010.5123332 ],
#        [  90015.44826862]])

# %%
pd.DataFrame(y_test,columns=['Actual']).merge(
    pd.DataFrame(y_pred.astype(int),columns=['Predicted']),left_index=True,right_index=True)
# Out:
#     Actual  Predicted
# 0   304900     382783
# 1    76540      83128
# 2    64300      32874
# 3   116430     116041
# 4   138520     108505
# 5  1001591    1294010
# 6    91920      90015

# %%
y_pred2 = model.predict(X_train)
y_pred2
# Out:
# array([[ 117077.76805211],
#        [  21913.39657099],
#        [ 118628.42015814],
#        [1035797.21077371],
#        [  70286.26083045],
#        [ 197067.96148559],
#        [ 182974.05375248],
#        [ 137063.40821016],
#        [  42187.42622414],
#        [  22706.08174669],
#        [ 108283.61406307],
#        [1101355.26614254],
#        [  64116.90710169],
#        [3551028.47142586],
#        [2967070.9190039 ],
#        [ 171408.79734433],
#        [  30058.94823533],
#        [ 213255.08887882]])

# %%
pd.DataFrame(y_train,columns=['Actual']).merge(
    pd.DataFrame(y_pred2.astype(int),columns=['Predicted']),left_index=True,right_index=True)
# Out:
#      Actual  Predicted
# 0    114830     117077
# 1     39450      21913
# 2    114040     118628
# 3   1028500    1035797
# 4     99900      70286
# 5    260260     197067
# 6    159560     182974
# 7    138510     137063
# 8     55680      42187
# 9     45880      22706
# 10   101740     108283
# 11  1011640    1101355
# 12    57020      64116
# 13  3568180    3551028
# 14  2982420    2967070
# 15   142240     171408
# 16    44890      30058
# 17   187540     213255

# %%
texas_em['Predicted 2018'] = [32874,117077,1035797,182974,137063,118628,213255,3551028,382783,1294010,2967070,
                              108505,70286,90015,171408,197067,83128,22706,1101355,30058,42187,108283,21913,116041,64116]

# %%
texas_em
# Out:
#                                  Location       Occupation     2003     2006  \
# 0                            Abilene, TX   All Occupations    53600    62670
# 1                           Amarillo, TX   All Occupations    95500   106470
# 2                   Austin-San Marcos, TX  All Occupations   651670   711080
# 3               Beaumont-Port Arthur, TX   All Occupations   153080   154910
# 4   Brownsville-Harlingen-San Benito, TX   All Occupations   112320   117680
# 5              Bryan-College Station, TX   All Occupations    75500    88910
# 6                     Corpus Christi, TX   All Occupations   157030   170810
# 7                             Dallas, TX   All Occupations  1890340  1990180
# 8                            El Paso, TX   All Occupations   251970   258140
# 9               Fort Worth-Arlington, TX   All Occupations   764710   818690
# 10                           Houston, TX   All Occupations  2057880  2378080
# ...

# %%
texas_em2 = texas_em

# %%
texas_em2['2021'] = ''

# %%
cols = ['Location', 'Loc ID', 'Occupation', 2003,2006,2009,2012,2015,2018,'Predicted 2018']
texas_em2 = texas_em2[cols]
texas_em2
# Out:
#                                  Location  Loc ID       Occupation     2003  \
# 0                            Abilene, TX        1  All Occupations    53600
# 1                           Amarillo, TX        2  All Occupations    95500
# 2                   Austin-San Marcos, TX       3  All Occupations   651670
# 3               Beaumont-Port Arthur, TX        4  All Occupations   153080
# 4   Brownsville-Harlingen-San Benito, TX        5  All Occupations   112320
# 5              Bryan-College Station, TX        6  All Occupations    75500
# 6                     Corpus Christi, TX        7  All Occupations   157030
# 7                             Dallas, TX        8  All Occupations  1890340
# 8                            El Paso, TX        9  All Occupations   251970
# 9               Fort Worth-Arlington, TX       10  All Occupations   764710
# 10                           Houston, TX       11  All Occupations  2057880
# ...

# %%
x_data2 = texas_em2[[2006, 2009, 2012, 2015,2018]].values

# %%
x_data2.shape
# Out:
# (25, 5)

# %%
Xnew= texas_em2.iloc[:,4:9].values.reshape(25, -1)
Xnew
# Out:
# array([[  62670.,   63330.,   62020.,   65070.,   64300.],
#        [ 106470.,  108690.,  109750.,  114450.,  114830.],
#        [ 711080.,  769370.,  812600.,  928810., 1028500.],
#        [ 154910.,  159930.,  157320.,  164920.,  159560.],
#        [ 117680.,  122990.,  125870.,  135710.,  138510.],
#        [  88910.,   91360.,   92990.,  189000.,  114040.],
#        [ 170810.,  177750.,  181240.,  189000.,  187540.],
#        [1990180., 2047600., 2097080., 2329820., 3568180.],
#        [ 258140.,  269250.,  275400.,  290630.,  304900.],
#        [ 818690.,  856430.,  879300.,  973010., 1001591.],
#        [2378080., 2563840., 2640640., 2929970., 2982420.],
#        [ 113000.,  121180.,  127320.,  132490.,  138520.],
#        [  82410.,   86940.,   90020.,   96340.,   99900.],
#        [  88160.,   94330.,   98130.,   98530.,   91920.],
#        [ 122380.,  123840.,  125800.,  137110.,  142240.],
#        [ 203380.,  220110.,  227710.,  243340.,  260260.],
# ...

# %%
Xnew.shape
# Out:
# (25, 5)

# %%
ynew = model.predict(Xnew)
ynew
# Out:
# array([[  93972.32649927],
#        [ 170048.1795664 ],
#        [1743122.0362949 ],
#        [ 312499.17594135],
#        [ 210187.80433435],
#        [ 684439.0496098 ],
#        [ 293465.36935974],
#        [5418966.50057577],
#        [ 495552.58986501],
#        [1954667.71841541],
#        [5797061.58720072],
#        [ 144272.37072792],
#        [ 117353.41578478],
#        [  80037.2170127 ],
#        [ 237749.44587336],
#        [ 379800.43185318],
#        [ 101574.78882386],
#        [  25566.95171826],
#        [1836378.06507866],
#        [  71190.95355553],
#        [  62839.24108386],
#        [ 163667.15411524],
#        [ -33814.55242909],
#        [ 187768.29344494],
#        [  73947.16586047]])

# %%
texas_em2[2021] = ynew.astype(int)

# %%
texas_em2
# Out:
#                                  Location  Loc ID       Occupation     2003  \
# 0                            Abilene, TX        1  All Occupations    53600
# 1                           Amarillo, TX        2  All Occupations    95500
# 2                   Austin-San Marcos, TX       3  All Occupations   651670
# 3               Beaumont-Port Arthur, TX        4  All Occupations   153080
# 4   Brownsville-Harlingen-San Benito, TX        5  All Occupations   112320
# 5              Bryan-College Station, TX        6  All Occupations    75500
# 6                     Corpus Christi, TX        7  All Occupations   157030
# 7                             Dallas, TX        8  All Occupations  1890340
# 8                            El Paso, TX        9  All Occupations   251970
# 9               Fort Worth-Arlington, TX       10  All Occupations   764710
# 10                           Houston, TX       11  All Occupations  2057880
# ...

# %%
texas_em2.to_csv("Texas Predicted 2021.csv")

# %%
texas_em2 =pd.melt(texas_em,id_vars=['Location','Occupation', 'Loc ID'], value_vars =[2003,2006,2009,2012,2015,2018,2021])

# %%
texas_em2
# Out:
#                                   Location       Occupation  Loc ID variable  \
# 0                             Abilene, TX   All Occupations       1     2003
# 1                            Amarillo, TX   All Occupations       2     2003
# 2                    Austin-San Marcos, TX  All Occupations       3     2003
# 3                Beaumont-Port Arthur, TX   All Occupations       4     2003
# 4    Brownsville-Harlingen-San Benito, TX   All Occupations       5     2003
# 5               Bryan-College Station, TX   All Occupations       6     2003
# 6                      Corpus Christi, TX   All Occupations       7     2003
# 7                              Dallas, TX   All Occupations       8     2003
# 8                             El Paso, TX   All Occupations       9     2003
# 9                Fort Worth-Arlington, TX   All Occupations      10     2003
# 10                            Houston, TX   All Occupations      11     2003
# ...
