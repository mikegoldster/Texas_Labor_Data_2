# %%
import pandas as pd

# %%
df=pd.read_csv('FinalClean3.csv')
# Out:
# C:\Users\atwit\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (3,5,8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#   State   REGION                           Occupation Total_Employee  \
# 0    TX  Abilene               MANAGEMENT OCCUPATIONS           3230
# 1    TX  Abilene                     CHIEF EXECUTIVES            270
# 2    TX  Abilene      GENERAL AND OPERATIONS MANAGERS           1310
# 3    TX  Abilene  ADVERTISING AND PROMOTIONS MANAGERS             40
# 4    TX  Abilene                   MARKETING MANAGERS             60
#
#    Hourly_Mean Annual_Mean      Year     FIPS           lat         long
# 0        24.56       51080  1/1/2000  48253.0  -100.0227588  32.96023636
# 1        38.44       79950  1/1/2000  48253.0  -100.0196878  32.96019936
# 2        24.34       50630  1/1/2000  48253.0  -100.0178718  32.96020936
# 3        22.63       47060  1/1/2000  48253.0  -100.0163558  32.96022036
# 4        24.48       50910  1/1/2000  48253.0  -100.0003678  32.96015836

# %%
df.to_html('employCurrent.html')

# %%
dff=pd.read_csv('Texas Predicted 2021.csv')

# %%
dff.head()
# Out:
#    Unnamed: 0                               Location  Loc ID       Occupation  \
# 0           0                           Abilene, TX        1  All Occupations
# 1           1                          Amarillo, TX        2  All Occupations
# 2           2                  Austin-San Marcos, TX       3  All Occupations
# 3           3              Beaumont-Port Arthur, TX        4  All Occupations
# 4           4  Brownsville-Harlingen-San Benito, TX        5  All Occupations
#
#      2003    2006    2009      2012      2015     2018  Predicted 2018  \
# 0   53600   62670   63330   62020.0   65070.0    64300           32874
# 1   95500  106470  108690  109750.0  114450.0   114830          117077
# 2  651670  711080  769370  812600.0  928810.0  1028500         1035797
# 3  153080  154910  159930  157320.0  164920.0   159560          182974
# 4  112320  117680  122990  125870.0  135710.0   138510          137063
#
#       2021
# 0    93972
# 1   170048
# 2  1743122
# 3   312499
# ...

# %%
dff=dff.drop(['Unnamed: 0'], axis=1)

# %%
dff.to_html('employPredict.html')
