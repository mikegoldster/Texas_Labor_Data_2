# %%
# import dpendencies 
import pandas as pd
import numpy as np
import os

# %%
df1 = pd.read_excel("May 2010.xls")
df2 = pd.read_excel("May 2011.xls")
df3 = pd.read_excel("May 2012.xls")
df4 = pd.read_excel("May 2013.xls")
df5 = pd.read_excel("May 2014.xlsx")
df6 = pd.read_excel("May 2015.xlsx")
df7 = pd.read_excel("May 2016.xlsx")
df8 = pd.read_excel("May 2017.xlsx")

# %%
dfa=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8])
dfa
# Out:
# C:\Users\tolania\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#       ANNUAL   AREA          AREA_NAME  A_MEAN A_MEDIAN A_PCT10 A_PCT25  \
# 0        NaN  10180        Abilene, TX   34780    26800   16170   18510
# 1        NaN  10180        Abilene, TX   78880    67140   33880   45340
# 2        NaN  10180        Abilene, TX  123640   101950   32320   79310
# 3        NaN  10180        Abilene, TX   90940    77990   37160   50770
# 4        NaN  10180        Abilene, TX   85950    66970   45930   53700
# 5        NaN  10180        Abilene, TX   70170    71400   35660   47940
# ...

# %%
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10047 entries, 0 to 10046
# Data columns (total 25 columns):
# PRIM_STATE      10047 non-null object
# AREA            10047 non-null int64
# AREA_NAME       10047 non-null object
# OCC_CODE        10047 non-null object
# OCC_TITLE       10047 non-null object
# OCC_GROUP       10047 non-null object
# TOT_EMP         10047 non-null object
# EMP_PRSE        10047 non-null object
# JOBS_1000       10047 non-null object
# LOC QUOTIENT    10047 non-null object
# H_MEAN          10047 non-null object
# A_MEAN          10047 non-null object
# MEAN_PRSE       10047 non-null object
# H_PCT10         10047 non-null object
# H_PCT25         10047 non-null object
# H_MEDIAN        10047 non-null object
# H_PCT75         10047 non-null object
# H_PCT90         10047 non-null object
# A_PCT10         10047 non-null object
# A_PCT25         10047 non-null object
# A_MEDIAN        10047 non-null object
# A_PCT75         10047 non-null object
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9888 entries, 0 to 9887
# Columns: 256 entries, PRIM_STATE to Column231
# dtypes: float64(231), int64(1), object(24)
# memory usage: 19.3+ MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9822 entries, 0 to 9821
# Data columns (total 25 columns):
# PRIM_STATE      9822 non-null object
# AREA            9822 non-null int64
# AREA_NAME       9822 non-null object
# OCC_CODE        9822 non-null object
# OCC_TITLE       9822 non-null object
# GROUP           594 non-null object
# TOT_EMP         9822 non-null object
# EMP_PRSE        9822 non-null object
# JOBS_1000       9822 non-null object
# LOC QUOTIENT    9822 non-null object
# H_MEAN          9822 non-null object
# A_MEAN          9822 non-null object
# MEAN_PRSE       9822 non-null object
# H_PCT10         9822 non-null object
# H_PCT25         9822 non-null object
# H_MEDIAN        9822 non-null object
# H_PCT75         9822 non-null object
# H_PCT90         9822 non-null object
# A_PCT10         9822 non-null object
# A_PCT25         9822 non-null object
# A_MEDIAN        9822 non-null object
# A_PCT75         9822 non-null object
# ...

# %%
df1
# Out:
#      PRIM_STATE   AREA          AREA_NAME OCC_CODE  \
# 0            TX  10180        Abilene, TX  00-0000
# 1            TX  10180        Abilene, TX  11-0000
# 2            TX  10180        Abilene, TX  11-1011
# 3            TX  10180        Abilene, TX  11-1021
# 4            TX  10180        Abilene, TX  11-2022
# 5            TX  10180        Abilene, TX  11-3011
# 6            TX  10180        Abilene, TX  11-3021
# 7            TX  10180        Abilene, TX  11-3031
# 8            TX  10180        Abilene, TX  11-3071
# 9            TX  10180        Abilene, TX  11-9021
# 10           TX  10180        Abilene, TX  11-9032
# 11           TX  10180        Abilene, TX  11-9033
# 12           TX  10180        Abilene, TX  11-9051
# 13           TX  10180        Abilene, TX  11-9111
# 14           TX  10180        Abilene, TX  11-9141
# 15           TX  10180        Abilene, TX  11-9151
# 16           TX  10180        Abilene, TX  13-0000
# ...
