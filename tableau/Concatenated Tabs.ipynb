# %%
# IMPORT DEPENDENCIES
import pandas as pd
import numpy as np
import os

# %%
file_path = r'C:\Users\tolania\OneDrive - Amni International Petroleum Company\Desktop\Project 3\Combined_Data.xlsx'

# %%
df = pd.read_excel(file_path, sheet_name=None)

# %%
cdf= pd.concat(df,sort=False)
cdf
# Out:
#            YEAR          AREA_NAME             OCC_CODE  \
# 2000 0     2000    Abilene, TX MSA              11-0000
#      1     2000    Abilene, TX MSA              11-1011
#      2     2000    Abilene, TX MSA              11-1021
#      3     2000    Abilene, TX MSA  2011-11-01 00:00:00
#      4     2000    Abilene, TX MSA  2021-11-01 00:00:00
#      5     2000    Abilene, TX MSA  2022-11-01 00:00:00
#      6     2000    Abilene, TX MSA  2031-11-01 00:00:00
#      7     2000    Abilene, TX MSA  3011-11-01 00:00:00
#      8     2000    Abilene, TX MSA  3021-11-01 00:00:00
#      9     2000    Abilene, TX MSA  3031-11-01 00:00:00
#      10    2000    Abilene, TX MSA  3040-11-01 00:00:00
#      11    2000    Abilene, TX MSA  3051-11-01 00:00:00
#      12    2000    Abilene, TX MSA  3061-11-01 00:00:00
#      13    2000    Abilene, TX MSA  3071-11-01 00:00:00
#      14    2000    Abilene, TX MSA  9021-11-01 00:00:00
#      15    2000    Abilene, TX MSA  9032-11-01 00:00:00
# ...

# %%
cdf.to_excel('concat.xlsx')
