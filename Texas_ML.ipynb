# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
texas_labor = "Employment_Data/Combined_Data.csv"

texas_df = pd.read_csv(texas_labor)
texas_df.head()
# Out:
#                        Location       Occupation  2003 Total Employees  \
# 0               Abilene, TX MSA  All Occupations               53600.0
# 1              Amarillo, TX MSA  All Occupations               95500.0
# 2     Austin-San Marcos, TX MSA  All Occupations              651670.0
# 3  Beaumont-Port Arthur, TX MSA  All Occupations              153080.0
# 4             Brazoria, TX PMSA  All Occupations               75590.0
#
#    2003 Hourly Mean  2003 Annual Mean  2003 Hourly Median  2003 Annual Median  \
# 0             13.33           27730.0               10.24             21290.0
# 1             14.32           29790.0               10.94             22750.0
# 2             18.18           37820.0               13.95             29010.0
# 3             15.58           32410.0               12.15             25260.0
# 4             15.98           33230.0               12.98             26990.0
#
#   2006 Total Employees 2006 Hourly Mean 2006 Annual Mean        ...          \
# 0                62670            13.77            28650        ...
# 1               106470            15.36            31950        ...
# 2               711080            19.19            39910        ...
# 3               154910             16.1            33480        ...
# 4               117680             12.6            26200        ...
#
#   2012 Total Employees 2012 Hourly Mean  2012 Annual Mean  2012 Hourly Median  \
# 0               62,020            17.31            36,000               13.56
# 1              109,750            18.85            39,200               14.43
# 2              812,600            22.64            47,080               17.12
# 3              157,320            20.11            41,830               16.07
# 4              125,870            15.44            32,120               10.76
#
#    2012 Annual Median  2015 Total Employees  2015 Hourly Mean  \
# 0              28,200                65,070             18.70
# 1              30,010               114,450             19.66
# 2              35,620               928,810             23.83
# 3              33,420               164,920             21.51
# 4              22,390               135,710             16.21
#
#   2015 Annual Mean  2015 Hourly Median 2015 Annual Median
# 0           38,900               14.61             30,400
# 1           40,900               14.93             31,050
# 2           49,560               17.95             37,330
# 3           44,730               16.88             35,100
# 4           33,710               11.21             23,310
#
# [5 rows x 27 columns]

# %%
texas_df.count()
# Out:
# Location                 27
# Occupation               27
# 2003 Total Employees     27
# 2003 Hourly Mean         27
# 2003 Annual Mean         27
# 2003 Hourly Median       27
# 2003 Annual Median       27
# 2006 Total Employees    204
# 2006 Hourly Mean        204
# 2006 Annual Mean        204
# 2006 Hourly Median      204
# 2006 Annual Median      204
# 2009 Total Employees     26
# 2009 Hourly Mean         26
# 2009 Annual Mean         26
# 2009 Hourly Median       26
# 2009 Annual Median       26
# 2012 Total Employees     26
# 2012 Hourly Mean         26
# 2012 Annual Mean         26
# 2012 Hourly Median       26
# 2012 Annual Median       26
# 2015 Total Employees     26
# 2015 Hourly Mean         26
# 2015 Annual Mean         26
# 2015 Hourly Median       26
# 2015 Annual Median       26
# dtype: int64

# %%
texas_df = texas_df.dropna()

# %%
texas_df.count()
# Out:
# Location                26
# Occupation              26
# 2003 Total Employees    26
# 2003 Hourly Mean        26
# 2003 Annual Mean        26
# 2003 Hourly Median      26
# 2003 Annual Median      26
# 2006 Total Employees    26
# 2006 Hourly Mean        26
# 2006 Annual Mean        26
# 2006 Hourly Median      26
# 2006 Annual Median      26
# 2009 Total Employees    26
# 2009 Hourly Mean        26
# 2009 Annual Mean        26
# 2009 Hourly Median      26
# 2009 Annual Median      26
# 2012 Total Employees    26
# 2012 Hourly Mean        26
# 2012 Annual Mean        26
# 2012 Hourly Median      26
# 2012 Annual Median      26
# 2015 Total Employees    26
# 2015 Hourly Mean        26
# 2015 Annual Mean        26
# 2015 Hourly Median      26
# 2015 Annual Median      26
# dtype: int64

# %%
texas_df
# Out:
#                                     Location       Occupation  \
# 0                            Abilene, TX MSA  All Occupations
# 1                           Amarillo, TX MSA  All Occupations
# 2                  Austin-San Marcos, TX MSA  All Occupations
# 3               Beaumont-Port Arthur, TX MSA  All Occupations
# 4                          Brazoria, TX PMSA  All Occupations
# 5   Brownsville-Harlingen-San Benito, TX MSA  All Occupations
# 6              Bryan-College Station, TX MSA  All Occupations
# 7                     Corpus Christi, TX MSA  All Occupations
# 8                            Dallas, TX PMSA  All Occupations
# 9                            El Paso, TX MSA  All Occupations
# 10             Fort Worth-Arlington, TX PMSA  All Occupations
# 11             Galveston-Texas City, TX PMSA  All Occupations
# 12                          Houston, TX PMSA  All Occupations
# 13                    Killeen-Temple, TX MSA  All Occupations
# 14                            Laredo, TX MSA  All Occupations
# 15                 Longview-Marshall, TX MSA  All Occupations
# 16                           Lubbock, TX MSA  All Occupations
# 17          McAllen-Edinburg-Mission, TX MSA  All Occupations
# 18                    Odessa-Midland, TX MSA  All Occupations
# 19                        San Angelo, TX MSA  All Occupations
# 20                           San Antonio, TX  All Occupations
# 21                   Sherman-Denison, TX MSA  All Occupations
# 22           Texarkana, TX-Texarkana, AR MSA  All Occupations
# 23                             Tyler, TX MSA  All Occupations
# 24                          Victoria, TX MSA  All Occupations
# 25                              Waco, TX MSA  All Occupations
#
#     2003 Total Employees  2003 Hourly Mean  2003 Annual Mean  \
# 0                53600.0             13.33           27730.0
# 1                95500.0             14.32           29790.0
# 2               651670.0             18.18           37820.0
# 3               153080.0             15.58           32410.0
# 4                75590.0             15.98           33230.0
# 5               112320.0             12.05           25060.0
# 6                75500.0             15.69           32630.0
# 7               157030.0             14.78           30730.0
# 8              1890340.0             18.35           38170.0
# 9               251970.0             13.46           28000.0
# 10              764710.0             17.35           36080.0
# 11               87250.0             16.77           34880.0
# 12             2057880.0             18.05           37540.0
# 13              100720.0             14.30           29740.0
# 14               74770.0             13.13           27320.0
# 15               91060.0             14.02           29150.0
# 16              115560.0             14.07           29270.0
# 17              176900.0             12.38           25740.0
# 18              102280.0             14.57           30310.0
# 19               43760.0             13.27           27600.0
# 20              704640.0             15.47           32180.0
# 21               41130.0             14.50           30150.0
# 22               50250.0             13.58           28240.0
# 23               84140.0             14.55           30260.0
# 24               34410.0             14.18           29500.0
# 25               93520.0             14.01           29150.0
#
#     2003 Hourly Median  2003 Annual Median 2006 Total Employees  \
# 0                10.24             21290.0                62670
# 1                10.94             22750.0               106470
# 2                13.95             29010.0               711080
# 3                12.15             25260.0               154910
# 4                12.98             26990.0               117680
# 5                 8.77             18250.0                88910
# 6                11.11             23120.0               170810
# 7                11.35             23610.0              1990180
# 8                13.95             29020.0               258140
# 9                 9.94             20680.0               818690
# 10               13.20             27460.0              2378080
# 11               12.99             27020.0               113000
# 12               13.68             28450.0                82410
# 13               10.96             22800.0                88160
# 14                9.54             19850.0               122380
# 15               10.96             22790.0               203380
# 16               10.75             22360.0                60170
# 17                8.76             18210.0                55430
# 18               11.08             23060.0                42270
# 19               10.28             21390.0               789240
# 20               11.62             24170.0                41810
# 21               11.44             23800.0                53740
# 22               11.04             22970.0                93100
# 23               11.21             23310.0                48020
# 24               10.79             22450.0                97530
# 25               10.81             22480.0                59760
#
#    2006 Hourly Mean 2006 Annual Mean        ...         2012 Total Employees  \
# 0             13.77            28650        ...                       62,020
# 1             15.36            31950        ...                      109,750
# 2             19.19            39910        ...                      812,600
# 3              16.1            33480        ...                      157,320
# 4              12.6            26200        ...                      125,870
# 5             18.44            38360        ...                       92,990
# 6             15.11            31420        ...                      181,240
# 7             19.68            40940        ...                    2,097,080
# 8             14.68            30540        ...                      275,400
# 9             18.02            37480        ...                      879,300
# 10            19.09            39710        ...                    2,640,640
# 11            14.88            30950        ...                      127,320
# 12            13.61            28300        ...                       90,020
# 13            14.99            31170        ...                       98,130
# 14               16            33280        ...                      125,800
# 15            13.02            27090        ...                      227,710
# 16            17.27            35920        ...                       76,870
# 17            15.73            32730        ...                       68,070
# 18            14.41            29970        ...                       44,660
# 19            16.08            33460        ...                      862,280
# 20             15.1            31410        ...                       40,790
# 21            14.82            30830        ...                       53,830
# 22            15.28            31790        ...                       92,570
# 23            15.49            32210        ...                       49,860
# 24            15.13            31480        ...                      100,300
# 25            14.67            30520        ...                       55,720
#
#    2012 Hourly Mean  2012 Annual Mean  2012 Hourly Median  2012 Annual Median  \
# 0             17.31            36,000               13.56              28,200
# 1             18.85            39,200               14.43              30,010
# 2             22.64            47,080               17.12              35,620
# 3             20.11            41,830               16.07              33,420
# 4             15.44            32,120               10.76              22,390
# 5             19.39            40,330               14.44              30,040
# 6             18.29            38,030               13.80              28,710
# 7             22.81            47,450               17.15              35,670
# 8             17.09            35,550               12.36              25,710
# 9             20.66            42,970               15.85              32,970
# 10            23.49            48,850               17.00              35,350
# 11            18.02            37,480               14.38              29,900
# 12            16.87            35,090               11.77              24,480
# 13            18.28            38,020               14.36              29,880
# 14            16.72            34,770               12.60              26,210
# 15            15.80            32,870               10.92              22,710
# 16            22.74            47,300               16.67              34,670
# 17            20.16            41,930               15.98              33,230
# 18            17.08            35,520               12.79              26,610
# 19            19.59            40,760               14.44              30,030
# 20            18.39            38,250               14.08              29,290
# 21            17.63            36,670               14.50              30,160
# 22            18.34            38,150               13.96              29,040
# 23            18.79            39,080               14.71              30,590
# 24            18.39            38,240               14.29              29,720
# 25            16.83            35,000               13.40              27,880
#
#     2015 Total Employees  2015 Hourly Mean 2015 Annual Mean  \
# 0                 65,070             18.70           38,900
# 1                114,450             19.66           40,900
# 2                928,810             23.83           49,560
# 3                164,920             21.51           44,730
# 4                135,710             16.21           33,710
# 5                101,040             20.17           41,960
# 6                189,000             20.18           41,970
# 7              2,329,820             24.27           50,480
# 8                290,630             17.78           36,980
# 9                973,010             21.90           45,560
# 10             2,929,970             24.92           51,830
# 11               132,490             19.33           40,200
# 12                96,340             16.85           35,050
# 13                98,530             19.49           40,530
# 14               137,110             19.07           39,670
# 15               243,340             16.26           33,810
# 16                92,930             25.43           52,890
# 17                75,380             22.98           47,800
# 18                46,450             17.99           37,410
# 19               947,350             21.03           43,740
# 20                43,280             18.38           38,220
# 21                56,760             18.28           38,020
# 22                98,350             19.94           41,470
# 23                42,290             19.52           40,600
# 24               109,740             19.49           40,540
# 25                56,400             18.75           38,990
#
#     2015 Hourly Median 2015 Annual Median
# 0                14.61             30,400
# 1                14.93             31,050
# 2                17.95             37,330
# 3                16.88             35,100
# 4                11.21             23,310
# 5                14.75             30,680
# 6                14.95             31,100
# 7                17.98             37,400
# 8                12.70             26,420
# 9                16.45             34,220
# 10               18.11             37,680
# 11               15.30             31,820
# 12               12.01             24,970
# 13               15.71             32,670
# 14               14.06             29,250
# 15               11.61             24,150
# 16               18.69             38,880
# 17               17.92             37,280
# 18               13.95             29,010
# 19               15.68             32,610
# 20               14.50             30,160
# 21               14.62             30,400
# 22               14.86             30,910
# 23               14.86             30,910
# 24               14.92             31,030
# 25               14.61             30,390
#
# [26 rows x 27 columns]

# %%
texas_em = texas_df.drop(columns=['2003 Hourly Mean','2006 Hourly Mean','2009 Hourly Mean','2012 Hourly Mean',
                                   '2015 Hourly Mean', '2003 Hourly Median','2006 Hourly Median','2009 Hourly Median',
                                  '2012 Hourly Median','2015 Hourly Median', '2003 Annual Median','2006 Annual Median','2009 Annual Median','2012 Annual Median',
                                   '2015 Annual Median', '2003 Annual Mean', '2006 Annual Mean', '2009 Annual Mean', '2012 Annual Mean',
                                    '2015 Annual Mean' ])

# %%
texas_em = texas_em.rename(columns = {'2003 Total Employees':2003,'2006 Total Employees':2006,'2009 Total Employees':2009,
                    '2012 Total Employees':2012,'2015 Total Employees':2015 })

# %%
texas_em[2006]=texas_em[2006].str.replace(',','').astype(float)

# %%
texas_em[2012]=texas_em[2012].str.replace(',','').astype(float)
texas_em[2015]=texas_em[2015].str.replace(',','').astype(float)

# %%
texas_em.head()
# Out:
#                        Location       Occupation      2003      2006  \
# 0               Abilene, TX MSA  All Occupations   53600.0   62670.0
# 1              Amarillo, TX MSA  All Occupations   95500.0  106470.0
# 2     Austin-San Marcos, TX MSA  All Occupations  651670.0  711080.0
# 3  Beaumont-Port Arthur, TX MSA  All Occupations  153080.0  154910.0
# 4             Brazoria, TX PMSA  All Occupations   75590.0  117680.0
#
#        2009      2012      2015
# 0   63330.0   62020.0   65070.0
# 1  108690.0  109750.0  114450.0
# 2  769370.0  812600.0  928810.0
# 3  159930.0  157320.0  164920.0
# 4  122990.0  125870.0  135710.0

# %%
i = 1
for location in texas_em['Location'].unique():
    texas_em.loc[texas_em['Location'] == location, "Loc ID"] = i
    i= i+1

# %%
texas_em['Loc ID'] = texas_em['Loc ID'].astype(int)

# %%
texas_em2 =pd.melt(texas_em,id_vars=['Location','Occupation', 'Loc ID'], value_vars =[2003,2006,2009,2012,2015])

# %%
texas_em2
# Out:
#                                      Location       Occupation  Loc ID  \
# 0                             Abilene, TX MSA  All Occupations       1
# 1                            Amarillo, TX MSA  All Occupations       2
# 2                   Austin-San Marcos, TX MSA  All Occupations       3
# 3                Beaumont-Port Arthur, TX MSA  All Occupations       4
# 4                           Brazoria, TX PMSA  All Occupations       5
# 5    Brownsville-Harlingen-San Benito, TX MSA  All Occupations       6
# 6               Bryan-College Station, TX MSA  All Occupations       7
# 7                      Corpus Christi, TX MSA  All Occupations       8
# 8                             Dallas, TX PMSA  All Occupations       9
# 9                             El Paso, TX MSA  All Occupations      10
# 10              Fort Worth-Arlington, TX PMSA  All Occupations      11
# 11              Galveston-Texas City, TX PMSA  All Occupations      12
# 12                           Houston, TX PMSA  All Occupations      13
# 13                     Killeen-Temple, TX MSA  All Occupations      14
# 14                             Laredo, TX MSA  All Occupations      15
# 15                  Longview-Marshall, TX MSA  All Occupations      16
# 16                            Lubbock, TX MSA  All Occupations      17
# 17           McAllen-Edinburg-Mission, TX MSA  All Occupations      18
# 18                     Odessa-Midland, TX MSA  All Occupations      19
# 19                         San Angelo, TX MSA  All Occupations      20
# 20                            San Antonio, TX  All Occupations      21
# 21                    Sherman-Denison, TX MSA  All Occupations      22
# 22            Texarkana, TX-Texarkana, AR MSA  All Occupations      23
# 23                              Tyler, TX MSA  All Occupations      24
# 24                           Victoria, TX MSA  All Occupations      25
# 25                               Waco, TX MSA  All Occupations      26
# 26                            Abilene, TX MSA  All Occupations       1
# 27                           Amarillo, TX MSA  All Occupations       2
# 28                  Austin-San Marcos, TX MSA  All Occupations       3
# 29               Beaumont-Port Arthur, TX MSA  All Occupations       4
# ..                                        ...              ...     ...
# 100           Texarkana, TX-Texarkana, AR MSA  All Occupations      23
# 101                             Tyler, TX MSA  All Occupations      24
# 102                          Victoria, TX MSA  All Occupations      25
# 103                              Waco, TX MSA  All Occupations      26
# 104                           Abilene, TX MSA  All Occupations       1
# 105                          Amarillo, TX MSA  All Occupations       2
# 106                 Austin-San Marcos, TX MSA  All Occupations       3
# 107              Beaumont-Port Arthur, TX MSA  All Occupations       4
# 108                         Brazoria, TX PMSA  All Occupations       5
# 109  Brownsville-Harlingen-San Benito, TX MSA  All Occupations       6
# 110             Bryan-College Station, TX MSA  All Occupations       7
# 111                    Corpus Christi, TX MSA  All Occupations       8
# 112                           Dallas, TX PMSA  All Occupations       9
# 113                           El Paso, TX MSA  All Occupations      10
# 114             Fort Worth-Arlington, TX PMSA  All Occupations      11
# 115             Galveston-Texas City, TX PMSA  All Occupations      12
# 116                          Houston, TX PMSA  All Occupations      13
# 117                    Killeen-Temple, TX MSA  All Occupations      14
# 118                            Laredo, TX MSA  All Occupations      15
# 119                 Longview-Marshall, TX MSA  All Occupations      16
# 120                           Lubbock, TX MSA  All Occupations      17
# 121          McAllen-Edinburg-Mission, TX MSA  All Occupations      18
# 122                    Odessa-Midland, TX MSA  All Occupations      19
# 123                        San Angelo, TX MSA  All Occupations      20
# 124                           San Antonio, TX  All Occupations      21
# 125                   Sherman-Denison, TX MSA  All Occupations      22
# 126           Texarkana, TX-Texarkana, AR MSA  All Occupations      23
# 127                             Tyler, TX MSA  All Occupations      24
# 128                          Victoria, TX MSA  All Occupations      25
# 129                              Waco, TX MSA  All Occupations      26
#
#     variable      value
# 0       2003    53600.0
# 1       2003    95500.0
# 2       2003   651670.0
# 3       2003   153080.0
# 4       2003    75590.0
# 5       2003   112320.0
# 6       2003    75500.0
# 7       2003   157030.0
# 8       2003  1890340.0
# 9       2003   251970.0
# 10      2003   764710.0
# 11      2003    87250.0
# 12      2003  2057880.0
# 13      2003   100720.0
# 14      2003    74770.0
# 15      2003    91060.0
# 16      2003   115560.0
# 17      2003   176900.0
# 18      2003   102280.0
# 19      2003    43760.0
# 20      2003   704640.0
# 21      2003    41130.0
# 22      2003    50250.0
# 23      2003    84140.0
# 24      2003    34410.0
# 25      2003    93520.0
# 26      2006    62670.0
# 27      2006   106470.0
# 28      2006   711080.0
# 29      2006   154910.0
# ..       ...        ...
# 100     2012    92570.0
# 101     2012    49860.0
# 102     2012   100300.0
# 103     2012    55720.0
# 104     2015    65070.0
# 105     2015   114450.0
# 106     2015   928810.0
# 107     2015   164920.0
# 108     2015   135710.0
# 109     2015   101040.0
# 110     2015   189000.0
# 111     2015  2329820.0
# 112     2015   290630.0
# 113     2015   973010.0
# 114     2015  2929970.0
# 115     2015   132490.0
# 116     2015    96340.0
# 117     2015    98530.0
# 118     2015   137110.0
# 119     2015   243340.0
# 120     2015    92930.0
# 121     2015    75380.0
# 122     2015    46450.0
# 123     2015   947350.0
# 124     2015    43280.0
# 125     2015    56760.0
# 126     2015    98350.0
# 127     2015    42290.0
# 128     2015   109740.0
# 129     2015    56400.0
#
# [130 rows x 5 columns]

# %%
plt.figure(figsize = (10,6))
plt.plot(texas_em2['value'], color= 'red')

# %%
# create model to ensure the model complies with 2018 data
# use 2003-2015 to train data
# once data is trained us 2018 to test data
# then use 2003-2018 data to predict 2021

# %%
from sklearn.preprocessing import MinMaxScaler
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Input, Dense, GRU, Embedding
from tensorflow.python.keras.optimizers import RMSprop
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard, ReduceLROnPlateau
import warnings     
warnings.filterwarnings('ignore')

# %%
texas_em2.shape
# Out:
# (130, 5)

# %%
target_year = texas_em2['variable']#the year I want to predict to
target_info = texas_em2[['Loc ID','value', 'variable']] #the info I want predicted

# %%
shift_years = 3
shift_steps = shift_years * 365 #number of days in 1 year

# %%
texas_targets = target_info.shift(-shift_steps)

# %%
texas_targets=target_info.head(+shift_steps + 5)
texas_targets.head()
# Out:
#    Loc ID     value variable
# 0       1   53600.0     2003
# 1       2   95500.0     2003
# 2       3  651670.0     2003
# 3       4  153080.0     2003
# 4       5   75590.0     2003

# %%
texas_em2.shape
# Out:
# (130, 5)

# %%
x_data = texas_em2[['variable','value','Loc ID']].values

# %%
x_data.shape
# Out:
# (130, 3)

# %%
y_data = texas_targets.values

# %%
y_data.shape
# Out:
# (130, 3)

# %%
train_split = 0.9

# %%
num_train = int(train_split * len(x_data))
num_train
# Out:
# 117

# %%
num_test = len(x_data)-num_train
num_test
# Out:
# 13

# %%
x_train = x_data[0:num_train]
x_test = x_data[num_train:]
len(x_train) + len(x_test)
# Out:
# 130

# %%
y_train = y_data[0:num_train]
y_test = y_data[num_train:]
len(y_train) + len(y_test)
# Out:
# 130

# %%
print("Min:", np.min(x_train))
print("Max:", np.max(x_train))
# Out:
# Min: 1
# Max: 2929970.0

# %%
x_scaler = MinMaxScaler()

# %%
x_train_scaled = x_scaler.fit_transform(x_train)
# Out:
# C:\Users\diamo\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
print("Min:", np.min(x_train_scaled))
print("Max:", np.max(x_train_scaled))
# Out:
# Min: 0.0
# Max: 1.0

# %%
x_test_scaled = x_scaler.transform(x_test)

# %%
y_scaler = MinMaxScaler()
y_train_scaled = y_scaler.fit_transform(y_train)
y_test_scaled = y_scaler.transform(y_test)
# Out:
# C:\Users\diamo\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
